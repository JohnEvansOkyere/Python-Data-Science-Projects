# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("student-performance-data.xlsx")

data
# Out:
#     school sex  age address famsize Pstatus                           Medu  \
# 0       GP   F   18       U     GT3       A               higher education
# 1       GP   F   17       U     GT3       T  primary education (4th grade)
# 2       GP   F   15       U     LE3       T  primary education (4th grade)
# 3       GP   F   15       U     GT3       T               higher education
# 4       GP   F   16       U     GT3       T            secondary education
# ..     ...  ..  ...     ...     ...     ...                            ...
# 644     MS   F   19       R     GT3       T               5th to 9th grade
# 645     MS   F   18       U     LE3       T            secondary education
# 646     MS   F   18       U     GT3       T  primary education (4th grade)
# 647     MS   M   17       U     LE3       T            secondary education
# 648     MS   M   18       R     LE3       T            secondary education
#
# ...

# %%
data.describe()
# Out:
#               age  traveltime   studytime    failures      famrel    freetime  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    1.568567    1.930663    0.221880    3.930663    3.180277
# std      1.218138    0.748660    0.829510    0.593235    0.955717    1.051093
# min     15.000000    1.000000    1.000000    0.000000    1.000000    1.000000
# 25%     16.000000    1.000000    1.000000    0.000000    4.000000    3.000000
# 50%     17.000000    1.000000    2.000000    0.000000    4.000000    3.000000
# 75%     18.000000    2.000000    2.000000    0.000000    5.000000    4.000000
# max     22.000000    4.000000    4.000000    3.000000    5.000000    5.000000
#
#             goout        Dalc        Walc      health    absences          G1  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.184900    1.502311    2.280431    3.536210    3.659476   11.399076
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    object
#  7   Fedu        649 non-null    object
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      577 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
data.isnull().sum()
# Out:
# school         0
# sex            0
# age            0
# address        0
# famsize        0
# Pstatus        0
# Medu           0
# Fedu           0
# Mjob           0
# Fjob           0
# reason        72
# guardian       0
# traveltime     0
# studytime      0
# failures       0
# schoolsup      0
# famsup         0
# paid           0
# activities     0
# nursery        0
# higher         0
# internet       0
# romantic       0
# famrel         0
# freetime       0
# goout          0
# Dalc           0
# Walc           0
# health         0
# absences       0
# G1             0
# G2             0
# G3             0
# dtype: int64

# %%
data.duplicated().count()
# Out:
# 649

# %%
#DATA EXOPLORATION

# %%
pd.set_option('display.max_columns', None)
data.head()
# Out:
#   school sex  age address famsize Pstatus                           Medu  \
# 0     GP   F   18       U     GT3       A               higher education
# 1     GP   F   17       U     GT3       T  primary education (4th grade)
# 2     GP   F   15       U     LE3       T  primary education (4th grade)
# 3     GP   F   15       U     GT3       T               higher education
# 4     GP   F   16       U     GT3       T            secondary education
#
#                             Fedu     Mjob      Fjob  reason guardian  \
# 0               higher education  at_home   teacher  course   mother
# 1  primary education (4th grade)  at_home     other  course   father
# 2  primary education (4th grade)  at_home     other     NaN   mother
# 3               5th to 9th grade   health  services    home   mother
# 4            secondary education    other     other    home   father
#
#    traveltime  studytime  failures schoolsup famsup paid activities nursery  \
# ...

# %%
grades = data['grades'] = data.iloc[:, 31:33].sum(axis=1)

grades.head()
# Out:
# 0    22
# 1    22
# 2    25
# 3    28
# 4    26
# dtype: int64

# %%
sns.catplot(x='studytime',y='grades',data=data)

# %%
xpoints = data['studytime']
ypoints = data['grades']

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# #CORRELATION ANALYSIS

# %%
#calculate the correlation matrix

cor_matrix = data.corr()

cor_matrix
# Out:
#                  age  traveltime  studytime  failures    famrel  freetime  \
# age         1.000000    0.034490  -0.008415  0.319968 -0.020559 -0.004910
# traveltime  0.034490    1.000000  -0.063154  0.097730 -0.009521  0.000937
# studytime  -0.008415   -0.063154   1.000000 -0.147441 -0.004127 -0.068829
# failures    0.319968    0.097730  -0.147441  1.000000 -0.062645  0.108995
# famrel     -0.020559   -0.009521  -0.004127 -0.062645  1.000000  0.129216
# freetime   -0.004910    0.000937  -0.068829  0.108995  0.129216  1.000000
# goout       0.112805    0.057454  -0.075442  0.045078  0.089707  0.346352
# Dalc        0.134768    0.092824  -0.137585  0.105949 -0.075767  0.109904
# Walc        0.086357    0.057007  -0.214925  0.082266 -0.093511  0.120244
# health     -0.008750   -0.048261  -0.056433  0.035588  0.109559  0.084526
# absences    0.149998   -0.008149  -0.118389  0.122779 -0.089534 -0.018716
# G1         -0.174322   -0.154120   0.260875 -0.384210  0.048795 -0.094497
# ...

# %%
#visualizing the correlation matrix using heatmap

plt.figure(figsize=(10,8))
sns.heatmap(cor_matrix, annot = True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
# Correlation between 'study_hours' and 'grades'

studytime_grades_corr = data['studytime'].corr(data['grades'])
print(f"Correlation between study hours and grades: {studytime_grades_corr:.2f}")

"""In summary, a correlation coefficient of 0.25 suggests a positive but relatively weak correlation between study hours
and grades. It indicates that, on average, students who study more tend to have slightly higher grades, but the 
relationship is not extremely strong. Always interpret correlation in the context of your specific dataset and consider
additional factors that might contribute to the observed relationship."""
# Out:
# Correlation between study hours and grades: 0.25
# 'In summary, a correlation coefficient of 0.25 suggests a positive but relatively weak correlation between study hours\nand grades. It indicates that, on average, students who study more tend to have slightly higher grades, but the \nrelationship is not extremely strong. Always interpret correlation in the context of your specific dataset and consider\nadditional factors that might contribute to the observed relationship.'

# %%
sns.heatmap(data.isnull(), yticklabels=False, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
data.dropna(inplace=True)

# %%
sns.heatmap(data.isnull(), yticklabels=False, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
data.head()
# Out:
#   school sex  age address famsize Pstatus                           Medu  \
# 0     GP   F   18       U     GT3       A               higher education
# 1     GP   F   17       U     GT3       T  primary education (4th grade)
# 3     GP   F   15       U     GT3       T               higher education
# 4     GP   F   16       U     GT3       T            secondary education
# 5     GP   M   16       U     LE3       T               higher education
#
#                             Fedu      Mjob      Fjob      reason guardian  \
# 0               higher education   at_home   teacher      course   mother
# 1  primary education (4th grade)   at_home     other      course   father
# 3               5th to 9th grade    health  services        home   mother
# 4            secondary education     other     other        home   father
# 5            secondary education  services     other  reputation   mother
#
#    traveltime  studytime  failures schoolsup famsup paid activities nursery  \
# ...

# %%
M=data['grades'].max()
N=data['grades'].min()
print(f"maximum grade is {M} and minimum is {N}")
# Out:
# maximum grade is 38 and minimum is 0

# %%
data = ['sex', '']

# %%
data = data.sort_values(by='G1')

data
# Out:
#     school sex  age address famsize Pstatus                           Medu  \
# 0       GP   F   18       U     GT3       A               higher education
# 569     MS   M   18       U     GT3       T            secondary education
# 567     MS   M   18       R     GT3       T            secondary education
# 572     MS   F   16       U     GT3       A            secondary education
# 603     MS   F   18       R     LE3       A               higher education
# ..     ...  ..  ...     ...     ...     ...                            ...
# 606     MS   F   17       U     GT3       T               higher education
# 344     GP   M   18       U     LE3       T               higher education
# 349     GP   F   17       U     GT3       T            secondary education
# 113     GP   M   15       U     LE3       T               higher education
# 617     MS   F   18       U     LE3       T  primary education (4th grade)
#
# ...

# %%
# Assuming 'Grades' is the column representing student performance
performance_trends = data.groupby('grades')[['G1','G2','G3']].mean()

performance_trends.head(10)
# Out:
#                G1         G2        G3
# grades
# 0        6.666667   0.000000  0.000000
# 7        7.500000   7.000000  0.000000
# 8        8.000000   8.000000  0.000000
# 9       11.000000   9.000000  0.000000
# 11      10.000000  10.000000  1.000000
# 12       5.000000   5.500000  6.500000
# 13       8.000000   6.000000  7.000000
# 14       7.200000   6.400000  7.600000
# 15       7.181818   7.363636  7.636364
# 16       7.928571   7.928571  8.071429

# %%
# Plotting
plt.figure(figsize=(10, 6))
plt.plot(performance_trends.index, performance_trends.values, marker='o')
plt.title('Student Performance Trends Over Time')
plt.xlabel('Academic Year or Semester')
plt.ylabel('Average Grades')
plt.legend(title=['G1','G2','G3'])
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
