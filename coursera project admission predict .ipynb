# %%
# !cat admission.predict_csv
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import pandas as pd

# %%
df = pd.read_csv("Admission_Predict.csv")
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# 0           1              0.92
# 1           1              0.76
# 2           1              0.72
# 3           1              0.80
# 4           0              0.65
# ..        ...               ...
# 395         1              0.82
# 396         1              0.84
# 397         1              0.91
# 398         0              0.67
# 399         1              0.95
#
# [400 rows x 9 columns]

# %%
df = pd.read_csv('Admission_Predict.csv',index_col=0)
df.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# 2                  1              0.76
# 3                  1              0.72
# 4                  1              0.80
# 5                  0              0.65

# %%
    new_df = df.rename(columns = {
        'GRE Score':'Class Score', 'TOEFL Score':'NEW Score',
                   'University Rating':'University Rating', 
                   'SOP': 'Statement of Purpose','LOR': 'Letter of Recommendation',
                   'CGPA':'CGPA', 'Research':'Research',
                   'Chance of Admit':'Chance of Admit'
    })
new_df
# Out:
#             Class Score  NEW Score  University Rating  Statement of Purpose  \
# Serial No.
# 1                   337        118                  4                   4.5
# 2                   324        107                  4                   4.0
# 3                   316        104                  3                   3.0
# 4                   322        110                  3                   3.5
# 5                   314        103                  2                   2.0
# ...                 ...        ...                ...                   ...
# 396                 324        110                  3                   3.5
# 397                 325        107                  3                   3.0
# 398                 330        116                  4                   5.0
# 399                 312        103                  3                   3.5
# 400                 333        117                  4                   5.0
#
#             LOR   CGPA  Research  Chance of Admit
# Serial No.
# 1            4.5  9.65         1              0.92
# 2            4.5  8.87         1              0.76
# 3            3.5  8.00         1              0.72
# 4            2.5  8.67         1              0.80
# 5            3.0  8.21         0              0.65
# ...          ...   ...       ...               ...
# 396          3.5  9.04         1              0.82
# 397          3.5  9.11         1              0.84
# 398          4.5  9.45         1              0.91
# 399          4.0  8.78         0              0.67
# 400          4.0  9.66         1              0.95
#
# [400 rows x 8 columns]

# %%
new_df.columns
# Out:
# Index(['Class Score', 'NEW Score', 'University Rating', 'Statement of Purpose',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance of Admit '],
#       dtype='object')

# %%
new_df = new_df.rename(columns={'LOR':'Recommendations'})
new_df.tail()
# Out:
#             Class Score  NEW Score  University Rating  Statement of Purpose  \
# Serial No.
# 396                 324        110                  3                   3.5
# 397                 325        107                  3                   3.0
# 398                 330        116                  4                   5.0
# 399                 312        103                  3                   3.5
# 400                 333        117                  4                   5.0
#
#             LOR   CGPA  Research  Chance of Admit
# Serial No.
# 396          3.5  9.04         1              0.82
# 397          3.5  9.11         1              0.84
# 398          4.5  9.45         1              0.91
# 399          4.0  8.78         0              0.67
# 400          4.0  9.66         1              0.95

# %%
# So that works well, but it's a bit fragile. What if that was a tab instead of a space? Or two spaces?
# Another way is to create some function that does the cleaning and then tell renamed to apply that function
# across all of the data. Python comes with a handy string function to strip white space called "strip()".
# When we pass this in to rename we pass the function as the mapper parameter, and then indicate whether the
# axis should be columns or index (row labels)

new_dd =new_df.rename(mapper=str.strip,axis ='columns')
new_dd.head()
# Out:
#             Class Score  NEW Score  University Rating  Statement of Purpose  \
# Serial No.
# 1                   337        118                  4                   4.5
# 2                   324        107                  4                   4.0
# 3                   316        104                  3                   3.0
# 4                   322        110                  3                   3.5
# 5                   314        103                  2                   2.0
#
#             LOR  CGPA  Research  Chance of Admit
# Serial No.
# 1           4.5  9.65         1             0.92
# 2           4.5  8.87         1             0.76
# 3           3.5  8.00         1             0.72
# 4           2.5  8.67         1             0.80
# 5           3.0  8.21         0             0.65

# %%
new_df.columns = new_df.columns.str.lower()
new_df.columns
# Out:
# Index(['class score', 'new score', 'university rating', 'statement of purpose',
#        'lor ', 'cgpa', 'research', 'chance of admit '],
#       dtype='object')

# %%
# We can also use the df.columns attribute by assigning to it a list of column names which will directly
# rename the columns. This will directly modify the original dataframe and is very efficient especially when
# you have a lot of columns and you only want to change a few. This technique is also not affected by subtle
# errors in the column names, a problem that we just encountered. With a list, you can use the list index to
# change a certain value or use list comprehension to change all of the values

# As an example, lets change all of the column names to lower case. First we need to get our list
cols = list(df.columns)
# Then a little list comprehenshion
cols = [x.lower().strip() for x in cols]
# Then we just overwrite what is already in the .columns attribute
df.columns=cols
# And take a look at our results
df.head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 5                 314          103                  2  2.0  3.0  8.21
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 3                  1             0.72
# 4                  1             0.80
# 5                  0             0.65

# %%
cols = (df.columns)
cols = [x.lower().strip() for x in cols]
df.columns = cols
df
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 5                 314          103                  2  2.0  3.0  8.21
# ...               ...          ...                ...  ...  ...   ...
# 396               324          110                  3  3.5  3.5  9.04
# 397               325          107                  3  3.0  3.5  9.11
# 398               330          116                  4  5.0  4.5  9.45
# 399               312          103                  3  3.5  4.0  8.78
# 400               333          117                  4  5.0  4.0  9.66
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 3                  1             0.72
# 4                  1             0.80
# 5                  0             0.65
# ...              ...              ...
# 396                1             0.82
# 397                1             0.84
# 398                1             0.91
# 399                0             0.67
# 400                1             0.95
#
# [400 rows x 8 columns]

# %%
cols = (df.columns)
cols = [x.upper().strip() for x in cols]
df.columns = cols
df
# Out:
#             GRE SCORE  TOEFL SCORE  UNIVERSITY RATING  SOP  LOR  CGPA  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 5                 314          103                  2  2.0  3.0  8.21
# ...               ...          ...                ...  ...  ...   ...
# 396               324          110                  3  3.5  3.5  9.04
# 397               325          107                  3  3.0  3.5  9.11
# 398               330          116                  4  5.0  4.5  9.45
# 399               312          103                  3  3.5  4.0  8.78
# 400               333          117                  4  5.0  4.0  9.66
#
#             RESEARCH  CHANCE OF ADMIT
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 3                  1             0.72
# 4                  1             0.80
# 5                  0             0.65
# ...              ...              ...
# 396                1             0.82
# 397                1             0.84
# 398                1             0.91
# 399                0             0.67
# 400                1             0.95
#
# [400 rows x 8 columns]

# %% [markdown]
# QUERYING DATA FRAME

# %%
df.tail()
# Out:
#             GRE SCORE  TOEFL SCORE  UNIVERSITY RATING  SOP  LOR  CGPA  \
# Serial No.
# 396               324          110                  3  3.5  3.5  9.04
# 397               325          107                  3  3.0  3.5  9.11
# 398               330          116                  4  5.0  4.5  9.45
# 399               312          103                  3  3.5  4.0  8.78
# 400               333          117                  4  5.0  4.0  9.66
#
#             RESEARCH  CHANCE OF ADMIT
# Serial No.
# 396                1             0.82
# 397                1             0.84
# 398                1             0.91
# 399                0             0.67
# 400                1             0.95

# %%
cols = (df.columns)
cols = [x.lower().strip() for x in df.columns]
df.columns = cols
df
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 5                 314          103                  2  2.0  3.0  8.21
# ...               ...          ...                ...  ...  ...   ...
# 396               324          110                  3  3.5  3.5  9.04
# 397               325          107                  3  3.0  3.5  9.11
# 398               330          116                  4  5.0  4.5  9.45
# 399               312          103                  3  3.5  4.0  8.78
# 400               333          117                  4  5.0  4.0  9.66
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 3                  1             0.72
# 4                  1             0.80
# 5                  0             0.65
# ...              ...              ...
# 396                1             0.82
# 397                1             0.84
# 398                1             0.91
# 399                0             0.67
# 400                1             0.95
#
# [400 rows x 8 columns]

# %%
admit_mask = df['chance of admit'] > 0.7
admit_mask
# Out:
# Serial No.
# 1       True
# 2       True
# 3       True
# 4       True
# 5      False
#        ...
# 396     True
# 397     True
# 398     True
# 399    False
# 400     True
# Name: chance of admit, Length: 400, dtype: bool

# %%
df.where(admit_mask).head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1               337.0        118.0                4.0  4.5  4.5  9.65
# 2               324.0        107.0                4.0  4.0  4.5  8.87
# 3               316.0        104.0                3.0  3.0  3.5  8.00
# 4               322.0        110.0                3.0  3.5  2.5  8.67
# 5                 NaN          NaN                NaN  NaN  NaN   NaN
#
#             research  chance of admit
# Serial No.
# 1                1.0             0.92
# 2                1.0             0.76
# 3                1.0             0.72
# 4                1.0             0.80
# 5                NaN              NaN

# %%
df.where(admit_mask).dropna().head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1               337.0        118.0                4.0  4.5  4.5  9.65
# 2               324.0        107.0                4.0  4.0  4.5  8.87
# 3               316.0        104.0                3.0  3.0  3.5  8.00
# 4               322.0        110.0                3.0  3.5  2.5  8.67
# 6               330.0        115.0                5.0  4.5  3.0  9.34
#
#             research  chance of admit
# Serial No.
# 1                1.0             0.92
# 2                1.0             0.76
# 3                1.0             0.72
# 4                1.0             0.80
# 6                1.0             0.90

# %%
new = df['lor'] ==4.5
new
# Out:
# Serial No.
# 1       True
# 2       True
# 3      False
# 4      False
# 5      False
#        ...
# 396    False
# 397    False
# 398     True
# 399    False
# 400    False
# Name: lor, Length: 400, dtype: bool

# %%
df.where(new).head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1               337.0        118.0                4.0  4.5  4.5  9.65
# 2               324.0        107.0                4.0  4.0  4.5  8.87
# 3                 NaN          NaN                NaN  NaN  NaN   NaN
# 4                 NaN          NaN                NaN  NaN  NaN   NaN
# 5                 NaN          NaN                NaN  NaN  NaN   NaN
#
#             research  chance of admit
# Serial No.
# 1                1.0             0.92
# 2                1.0             0.76
# 3                NaN              NaN
# 4                NaN              NaN
# 5                NaN              NaN

# %%
df.where(new).dropna().head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1               337.0        118.0                4.0  4.5  4.5  9.65
# 2               324.0        107.0                4.0  4.0  4.5  8.87
# 12              327.0        111.0                4.0  4.0  4.5  9.00
# 13              328.0        112.0                4.0  4.0  4.5  9.10
# 24              334.0        119.0                5.0  5.0  4.5  9.70
#
#             research  chance of admit
# Serial No.
# 1                1.0             0.92
# 2                1.0             0.76
# 12               1.0             0.84
# 13               1.0             0.78
# 24               1.0             0.95

# %%
over = df['sop']<4.0
over
# Out:
# Serial No.
# 1      False
# 2      False
# 3       True
# 4       True
# 5       True
#        ...
# 396     True
# 397     True
# 398    False
# 399     True
# 400    False
# Name: sop, Length: 400, dtype: bool

# %%
df.where(over).dropna().tail()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 392             318.0        106.0                3.0  2.0  3.0  8.65
# 394             317.0        104.0                2.0  3.0  3.0  8.76
# 396             324.0        110.0                3.0  3.5  3.5  9.04
# 397             325.0        107.0                3.0  3.0  3.5  9.11
# 399             312.0        103.0                3.0  3.5  4.0  8.78
#
#             research  chance of admit
# Serial No.
# 392              0.0             0.71
# 394              0.0             0.77
# 396              1.0             0.82
# 397              1.0             0.84
# 399              0.0             0.67

# %%
df[df['chance of admit']>0.7].head()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 324          107                  4  4.0  4.5  8.87
# 3                 316          104                  3  3.0  3.5  8.00
# 4                 322          110                  3  3.5  2.5  8.67
# 6                 330          115                  5  4.5  3.0  9.34
#
#             research  chance of admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.76
# 3                  1             0.72
# 4                  1             0.80
# 6                  1             0.90

# %%
df[df['sop'] == 4.5].tail()
# Out:
#             gre score  toefl score  university rating  sop  lor  cgpa  \
# Serial No.
# 363               338          115                  5  4.5  5.0  9.23
# 366               330          114                  4  4.5  3.0  9.17
# 373               336          119                  4  4.5  4.0  9.62
# 383               324          110                  4  4.5  4.0  9.15
# 395               329          111                  4  4.5  4.0  9.23
#
#             research  chance of admit
# Serial No.
# 363                1             0.91
# 366                1             0.86
# 373                1             0.95
# 383                1             0.82
# 395                1             0.89

# %%
df[['gre score','chance of admit']].head()
# Out:
#             gre score  chance of admit
# Serial No.
# 1                 337             0.92
# 2                 324             0.76
# 3                 316             0.72
# 4                 322             0.80
# 5                 314             0.65

# %%
both = (df['gre score'] > 300) & (df['gre score'] > 7).head()
both
# Out:
# Serial No.
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
#        ...
# 396    False
# 397    False
# 398    False
# 399    False
# 400    False
# Name: gre score, Length: 400, dtype: bool

# %%
(df['gre score'] >300) &( df['chance of admit'] < 0.7)
# Out:
# Serial No.
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
#        ...
# 396    False
# 397    False
# 398    False
# 399     True
# 400    False
# Length: 400, dtype: bool

# %%
df['gre score'].gt(0.7).lt(0.9)
# Out:
# Serial No.
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 396    False
# 397    False
# 398    False
# 399    False
# 400    False
# Name: gre score, Length: 400, dtype: bool

# %% [markdown]
# INDEXING DATAFRAME

# %%
# Let's say that we don't want to index the DataFrame by serial numbers, but instead by the
# chance of admit. But lets assume we want to keep the serial number for later. So, lets
# preserve the serial number into a new column. We can do this using the indexing operator 
# on the string that has the column label. Then we can use the set_index to set index 
# of the column to chance of admit

# So we copy the indexed data into its own column
df['Serial Number'] = df.index
# Then we set the index to another column
df = df.set_index('lor')
df.head()
# Out:
#      gre score  toefl score  university rating  sop  cgpa  research  \
# lor
# 4.5        337          118                  4  4.5  9.65         1
# 4.5        324          107                  4  4.0  8.87         1
# 3.5        316          104                  3  3.0  8.00         1
# 2.5        322          110                  3  3.5  8.67         1
# 3.0        314          103                  2  2.0  8.21         0
#
#      chance of admit  Serial Number
# lor
# 4.5             0.92              1
# 4.5             0.76              2
# 3.5             0.72              3
# 2.5             0.80              4
# 3.0             0.65              5

# %%
df = df.reset_index()
df.head()
# Out:
#    lor  gre score  toefl score  university rating  sop  cgpa  research  \
# 0  4.5        337          118                  4  4.5  9.65         1
# 1  4.5        324          107                  4  4.0  8.87         1
# 2  3.5        316          104                  3  3.0  8.00         1
# 3  2.5        322          110                  3  3.5  8.67         1
# 4  3.0        314          103                  2  2.0  8.21         0
#
#    chance of admit  Serial Number
# 0             0.92              1
# 1             0.76              2
# 2             0.72              3
# 3             0.80              4
# 4             0.65              5

# %%
df = pd.read_csv('census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# 0         -0.193196          0.381066          0.582002         -0.467369
# 1         -2.915927         -3.012349          2.265971         -2.530799
# 2         17.647293         21.845705         19.243287         17.197872
# 3         -2.500690         -7.056824         -3.904217        -10.543299
# 4         -5.068871         -6.201001         -0.177537          0.177258
#
#    RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015
# 0     1.030015     0.826644     1.383282     1.724718     0.712594
# 1     7.606016    -2.626146    -2.722002     2.592270    -2.187333
# 2    15.844176    18.559627    22.727626    20.317142    18.293499
# 3    -4.874741    -2.758113    -7.167664    -3.978583   -10.543299
# 4    -5.088389    -4.363636    -5.403729     0.754533     1.107861
#
# [5 rows x 100 columns]

# %%
df['SUMLEV'].unique()
# Out:
# array([40, 50], dtype=int64)

# %%
df['CTYNAME'].unique()
# Out:
# array(['Alabama', 'Autauga County', 'Baldwin County', ..., 'Uinta County',
#        'Washakie County', 'Weston County'], dtype=object)

# %%
df=df[df['SUMLEV']==50]
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
# 5          57322              57322            57373  ...          1.807375
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# 1         -2.915927         -3.012349          2.265971         -2.530799
# 2         17.647293         21.845705         19.243287         17.197872
# 3         -2.500690         -7.056824         -3.904217        -10.543299
# 4         -5.068871         -6.201001         -0.177537          0.177258
# 5         -1.177622         -1.748766         -2.062535         -1.369970
#
#    RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015
# 1     7.606016    -2.626146    -2.722002     2.592270    -2.187333
# 2    15.844176    18.559627    22.727626    20.317142    18.293499
# 3    -4.874741    -2.758113    -7.167664    -3.978583   -10.543299
# 4    -5.088389    -4.363636    -5.403729     0.754533     1.107861
# 5     1.859511    -0.848580    -1.402476    -1.577232    -0.884411
#
# [5 rows x 100 columns]

# %%
df = df[['SUMLEV', 'REGION', 'DIVISION']]
df.head()
# Out:
#    SUMLEV  REGION  DIVISION
# 1      50       3         6
# 2      50       3         6
# 3      50       3         6
# 4      50       3         6
# 5      50       3         6

# %%
col_to_keep = ['SUMLEV', 'REGION','DIVISION']
df = df[col_to_keep]
df.head()
# Out:
#    SUMLEV  REGION  DIVISION
# 1      50       3         6
# 2      50       3         6
# 3      50       3         6
# 4      50       3         6
# 5      50       3         6

# %%
# The US Census data breaks down population estimates by state and county. We can load the data and 
# set the index to be a combination of the state and county values and see how pandas handles it in 
# a DataFrame. We do this by creating a list of the column identifiers we want to have indexed. And then 
# calling set index with this list and assigning the output as appropriate. We see here that we have 
# a dual index, first the state name and second the county name.
df = df.reset_index()
df = df.set_index('index','REGION')
df.head()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_2880\2022102108.py:7: FutureWarning: In a future version of pandas all arguments of DataFrame.set_index except for the argument 'keys' will be keyword-only.
#   df = df.set_index('index','REGION')
#        SUMLEV  REGION  DIVISION
# index
# 1          50       3         6
# 2          50       3         6
# 3          50       3         6
# 4          50       3         6
# 5          50       3         6

# %%
df.loc['Michigan', 'Washtenaw County']+
# Out:
#   Input In [39]
#     df.loc['Michigan', 'Washtenaw County']+
#                                            ^
# SyntaxError: invalid syntax

# %% [markdown]
# MISSING VALUES

# %%
# This can be useful for processing rows based on certain columns of data. Another useful operation is to be
# able to drop all of those rows which have any missing data, which can be done with the dropna() function.

mask = df.isnull()
mask.tail(10)

# %%
df.dropna().head(10)

# %%
# Note how the rows indexed with 2, 3, 7, and 11 are now gone. One of the handy functions that Pandas has for
# working with missing values is the filling function, fillna(). This function takes a number or parameters.
# You could pass in a single value which is called a scalar value to change all of the missing data to one
# value. This isn't really applicable in this case, but it's a pretty common use case.

# So, if we wanted to fill all missing values with 0, we would use fill
df.fillna(0, inplace = True)
df.head(10)

# %%
df=pd.read_csv('log.csv')
df.head(10)

# %%
# Next up is the method parameter(). The two common fill values are ffill and bfill. ffill is for forward
# filling and it updates an na value for a particular cell with the value from the previous row. bfill is
# backward filling, which is the opposite of ffill. It fills the missing values with the next valid value.
# It's important to note that your data needs to be sorted in order for this to have the effect you might
# want. Data which comes from traditional database management systems usually has no order guarantee, just
# like this data. So be careful.

# In Pandas we can sort either by index or by values. Here we'll just promote the time stamp to an index then
# sort on the index.
df = df.set_index('time')
df = df.sort_index()
df.head(20)

# %%
# If we look closely at the output though we'll notice that the index 
# isn't really unique. Two users seem to be able to use the system at the same 
# time. Again, a very common case. Let's reset the index, and use some 
# multi-level indexing on time AND user together instead,
# promote the user name to a second level of the index to deal with that issue.


df = df.reset_index()
df = df.set_index(['time', 'user'])
df.head(10)

# %%
# Now that we have the data indexed and sorted appropriately, we can fill the missing datas using ffill. It's
# good to remember when dealing with missing values so you can deal with individual columns or sets of columns
# by projecting them. So you don't have to fix all missing values in one command.
df=df.fillna(method= 'ffill')
df.head(10)
# Out:
#        SUMLEV  REGION  DIVISION
# index
# 1          50       3         6
# 2          50       3         6
# 3          50       3         6
# 4          50       3         6
# 5          50       3         6
# 6          50       3         6
# 7          50       3         6
# 8          50       3         6
# 9          50       3         6
# 10         50       3         6
